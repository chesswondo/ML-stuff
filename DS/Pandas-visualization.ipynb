# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
stud_perform = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
stud_perform
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
stud_perform['math score'].hist()

# %%
stud_perform.plot.scatter(x='math score', y='reading score')

# %%
sns.lmplot(x='math score', y='reading score', data=stud_perform)

# %%
sns.lmplot(x='math score', y='reading score', hue='gender', data=stud_perform)

# %%
sns.lmplot(x='math score', y='reading score', hue='gender', data=stud_perform, fit_reg=False)

# %%
ax = sns.lmplot(x='math score', y='reading score', hue='gender', data=stud_perform, fit_reg=False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
plt.plot(df.index, df.income)

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
df.plot()

# %%
sns.lineplot(data=df)

# %%
df['income'].plot()

# %%
df.plot(kind='line')

# %%
df.income.plot()

# %%
from google.colab import files
uploaded = files.upload()

df = pd.read_csv("dataset.txt", sep=" ")
sns.lmplot(x='x', y='y', data=df, fit_reg=False)
# Out:
#      <input type="file" id="files-54c42ab4-d57c-4eef-8f21-5f9c9a6add4f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54c42ab4-d57c-4eef-8f21-5f9c9a6add4f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
genom = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)
genom
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(genom, cmap="viridis")

# %%
dota = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)
dota
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
#print(dota.roles[0])
dota.roles = [len(dota.roles[i].split(",")) for i in range(len(dota.roles))]
dota
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr  roles
# 0            agi      3
# 1            str      4
# ...

# %%
plt.plot(dota.name, dota.roles)

# %%
dota.roles
# Out:
# 0      3
# 1      4
# 2      4
# 3      5
# 4      4
#       ..
# 112    4
# 113    4
# 114    6
# 115    4
# 116    4
# Name: roles, Length: 117, dtype: int64

# %%
max_ = 0
index = -1
for i in range(100):
  if list(dota.roles).count(i) > max_:
    max_ = list(dota.roles).count(i)
    index = i

print(index)
# Out:
# 4

# %%
iris = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(data=iris)

# %%
sns.violinplot(data=iris, y="petal length")

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(data=iris, hue="species")

# %%
iris.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
d = {'type': ['A', 'A', 'B', 'B'], 'value': [10, 14, 12, 23]}
my_data = pd.DataFrame(data=d)
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23
